# %% [markdown]
# This file shows how good (or bad) I marked the labels.
#
# To check labeling I'm trying to cluster all the abilities
# based on the labels they have and check results manually.

# %%
import json
from sklearn.cluster import KMeans

from atod import Abilities

# %%
all_abilities = Abilities.all().get_labels_list()
all_abilities.head()

X = all_abilities.drop(['id', 'name'], axis=1)

# %%
km = KMeans(n_clusters=35, random_state=0).fit(X)

# %% [markdown]
# ## Results

# %%
# spread abilities to their clusters
clusters = dict()
for ability, cluster in zip(all_abilities.iterrows(), km.labels_):
    clusters.setdefault(str(cluster), [])
    clusters[str(cluster)].append(ability[1]['name'])

print(json.dumps(clusters, indent=2))
# Out:
# {
#   "2": [
#     "mana_break",
#     "arrow",
#     "adaptive_strike",
#     "meat_hook",
#     "shackles",
#     "hellfire_blast",
#     "electric_vortex",
#     "magic_missile",
#     "frostbite",
#     "shackleshot",
#     "malefice",
#     "dragon_tail",
#     "poison_touch",
#     "battery_assault",
#     "sprout",
#     "flaming_lasso",
#     "greater_bash",
#     "nether_strike",
#     "homing_missile",
#     "unstable_concoction",
#     "cold_snap",
#     "earth_hurl_boulder",
#     "spirit_bear_entangle",
#     "chaos_bolt",
#     "fireblast",
#     "ensnare",
#     "snowball",
#     "duel",
#     "sleight_of_fist"
#   ],
#   "23": [
#     "silence",
#     "phase_shift",
#     "silence",
#     "crystal_nova",
#     "smoke_screen",
#     "crippling_fear"
#   ],
#   "13": [
#     "laser",
#     "gravekeepers_cloak",
#     "ancestral_spirit",
#     "geomagnetic_grip"
#   ],
#   "3": [
#     "blink",
#     "x_marks_the_spot",
#     "replicate",
#     "morph_replicate",
# ...
