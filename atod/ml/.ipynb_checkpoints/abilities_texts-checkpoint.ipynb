# %% [markdown]
# # Abilities texts
# This files shows how to use get access to abilities texts

# %%
from atod import Abilities

# %%
# get all texts for all abilities
texts = Abilities.all().get_texts()
texts.head()
# Out:
#      ID                                        description  \
# 0  5003  Burns an opponent's mana on each attack.  Mana...
# 1  5004  Short distance teleportation that allows Anti-...
# 2  5005  Increases Anti-Mage's resistance to magic dama...
# 3  5006  For each point of mana missing by the target u...
# 4  5007  Axe taunts nearby enemy units, forcing them to...
#
#                                                 lore             name  \
# 0  A modified technique of the Turstarkuri monks'...       mana_break
# 1  In his encounter with the Dead Gods, Anti-Mage...            blink
# 2  Years of meditation and obsession with revenge...     spell_shield
# 3  After bringing enemies to their knees, Anti-Ma...        mana_void
# 4  Mogul Khan's warcry taunts opponents into enga...  berserkers_call
#
#                                                notes  \
# 0  You can lifeleech the damage dealt by this ski...
# 1  You can use Blink to dodge incoming projectiles.
# ...

# %%
# pick description and name from texts
descriptions = texts[['description', 'name']]
descriptions.head()
# Out:
#                                          description             name
# 0  Burns an opponent's mana on each attack.  Mana...       mana_break
# 1  Short distance teleportation that allows Anti-...            blink
# 2  Increases Anti-Mage's resistance to magic dama...     spell_shield
# 3  For each point of mana missing by the target u...        mana_void
# 4  Axe taunts nearby enemy units, forcing them to...  berserkers_call

# %%
# create a corpus from descriptions
corpus = list(descriptions['description'])
# Out:
# ["Burns an opponent's mana on each attack.  Mana Break deals 60%% of the mana burned as damage to the target.\\n\\nMana Break is a Unique Attack Modifier, and does not stack with other Unique Attack Modifiers.",
#  'Short distance teleportation that allows Anti-Mage to move in and out of combat.',
#  "Increases Anti-Mage's resistance to magic damage.\\n\\nUpgradable by Aghanim's Scepter.",
#  'For each point of mana missing by the target unit, damage is dealt to it and surrounding enemies.  The main target is also mini-stunned.',
#  'Axe taunts nearby enemy units, forcing them to attack him, while he gains bonus armor during the duration.',
#  'Enrages an enemy unit, causing it to be slowed and take damage over time until it kills another unit or the duration ends. Axe gains movement speed for each unit affected with Battle Hunger.',
#  'When attacked, Axe performs a helix counter attack, dealing pure damage to all nearby enemies.',
# ...
