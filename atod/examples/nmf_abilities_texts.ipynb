# %% [markdown]
# # Topic modeling of abilities texts
# In this file I'm trying to cluster the abilities by performing topic modeling (with NMF decomposition) on their descriptions.

# %%
import pandas as pd
from pprint import pprint
from sklearn.decomposition import NMF
from nltk.stem.snowball import EnglishStemmer
from sklearn.feature_extraction.text import TfidfVectorizer

from atod import Abilities, Heroes

# %% [markdown]
# ## NMF

# %%
# create stop-words list
heroes = Heroes.all()
heroes_names = [h.name for h in heroes]
# names of heroes commonly occur in descriptions, so
# deleting them is a good idea
words_in_heroes_names = [word.lower() for name in heroes_names for word in name.split(' ')]

eng_stop_words = TfidfVectorizer(stop_words='english').get_stop_words()
stop_words = set(words_in_heroes_names + list(eng_stop_words) 
                 + ['font', 'color', '7998b5', 'target', 'enemy', 'friendly', 'allied',
                    'remnant', 'aghanim', 'scepter', 'units', 'deal damage'
                    'cause', 'creep'])
# Out:
# No abilities for this HeroID == 16

# %%
# get all texts for all abilities
texts = Abilities.all().get_texts()
# get abilities names and  descriptions
descriptions = texts[['description', 'name']]
corpus = [a.replace('\\n', ' ').replace('%%', '%') for a in descriptions['description']]
corpus.extend(['stun', 'silence', 
               'blink is short distance teleportation', 
               'silence', 
               'healing',
               'invisibility', 'area of usage', 'armor', 'percentage',
               'DOT is damage over time (seconds)',
               'summon or place a ward', 'illusions, images, duplicates, nemesisis',
               'critical damage', 'movement speed', 'attack speed'])

stemmer = EnglishStemmer()
stemmed_corpus = []
for doc in corpus:
    stemmed_corpus.append(' '.join([stemmer.stem(word) for word in doc.split(' ')]))

corpus = stemmed_corpus

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,  
                                   stop_words=stop_words,
                                   ngram_range=(1,3))
tfidf_vectorizer.fit(corpus)
tf_corpus = tfidf_vectorizer.transform(corpus)
tf_features_names = tfidf_vectorizer.get_feature_names()

tf_corpus.shape
# Out:
# (503, 1554)

# %%
nmf = NMF(n_components=40, init='nndsvd').fit(tf_corpus)

for topic_idx, topic in enumerate(nmf.components_):
    print("Topic %d:" % (topic_idx))
    print(", ".join([tf_features_names[i]
                    for i in topic.argsort()[:-10 - 1:-1]]))
# Out:
# Topic 0:
# unit, enemi unit, enemi, send, beast, radius, upgrad, unit damag, spells, swarm
# Topic 1:
# movement speed, movement, speed, increas movement, increas movement speed, increas, cast, slow movement speed, movement speed attack, bonus movement
# Topic 2:
# dispel, dispel type basic, type basic dispel, type basic, basic dispel, basic, dispel type, type, purg, magic
# Topic 3:
# damag enemi, damag enemi unit, deal damag enemi, damag, enemi unit, deal damag, deal, enemi, unit, area deal
# Topic 4:
# nearbi enemi, nearbi, enemi, nearbi enemi unit, burn, damag nearbi enemi, damag nearbi, radius, struck, damag
# Topic 5:
# damag time, time, deal damag, deal, deal damag time, damag, poison, time seconds, time slow, damag time slow
# Topic 6:
# level, base level, base, invok, base level quas, level quas, quas, level cabe68 exort, level cabe68, base level cabe68
# Topic 7:
# attack, damag attack, great, slow attack, allow, attack movement, poison slow, element, attack damag, attack slow
# Topic 8:
# area, unit area, enemi unit area, deton, area deal, area deal damag, raze area deal, raze, raze area, unit area cast
# Topic 9:
# ground, stun, slam, slam ground, stun damag, ground stun, slam ground stun, land, enemi land, stun damag nearbi
# Topic 10:
# heal, alli, nearbi alli, heal nearbi, heal nearbi alli, unit heal, nearbi, enemi unit heal, focus, rip
# Topic 11:
# attack speed, increas attack speed, increas attack, speed, increas, attack, gain increas, gain, gain increas attack, alli
# Topic 12:
# armor, reduc, reduc armor, imag, presenc, reduct, armor enemi, enemi armor, armor seconds, water
# Topic 13:
# damage, deal, deal damage, damage upgrad, extra, upgrad, physic damage, magic damage, magic, physic
# Topic 14:
# mana, equal, lose, point mana, mana pool, pool, spell, cost, total mana, restor
# Topic 15:
# critic, strike, critic strike, chanc, ad, hit, chanc deal, victim, strike enemi, bounti
# Topic 16:
# bonus, bonus damag, grant, deal bonus, damag, deal bonus damag, grant bonus, deal, damag buildings, buildings
# Topic 17:
# health, life, current health, current, drain, regener, drain health, base health, health regener, minimum
# Topic 18:
# seconds, seconds upgrad, channel, upgrad, arriv, exist, vortex, deal massiv, massiv, everi
# Topic 19:
# ward, summon, place, immun, ward attack enemi, ward attack, attack enemi, enemi unit structures, unit structures, structures ward immun
# Topic 20:
# ani, ani enemi, morphl, teleport ani, snowbal, teleport, abil, tether, point, launch
# Topic 21:
# friend, friend unit, unit, heal friend, heal friend unit, friend unit damag, friend hero, unit damag, instant, nearbi friend
# Topic 22:
# invis, becom, becom invis, hawk, trap, plant invis, plant, prevent, attack use, attack use ability
# Topic 23:
# creat, illus, energi, creat illus, terrorblad, deal damage, fractur, barrier, circular, cone
# Topic 24:
# percentag, beam, damag enemi heal, enemi heal, current health, current, heal percentag, dealt, spell, percentag current health
# Topic 25:
# teleport, short distanc, distanc teleport, short distanc teleport, distanc, short, teleport allow, distanc teleport allow, allow, combat
# Topic 26:
# second, damag second, burn, deal damag second, everi, damag, golem, deal, hp, max hp
# Topic 27:
# dispel, type strong dispel, type strong, strong dispel, strong, dispel type strong, type, dispel type, negat, remov
# Topic 28:
# silenc, enchant, spells, addit damag, damag silenc, addit, cast, damag spells, unit rune, rune
# Topic 29:
# uniqu attack, uniqu, modifiers, attack modifiers, uniqu attack modifiers, doe, attack, stack uniqu attack, modifier, uniqu attack modifier
# Topic 30:
# caus, miss, caus miss, attacks, miss attacks, blind, caus miss attacks, caus attack, chanc miss, drench
# Topic 31:
# enemies, nearbi enemies, nearbi, damag nearbi enemies, damag nearbi, attacked, slow nearbi enemies, loos, let, let loos
# Topic 32:
# allow, elements, allow manipul, provid increas, instanc provid increas, instanc provid, instanc, manipul, provid, provid increas attack
# Topic 33:
# hero, enemi hero, enemi, upgrad, kill, steal, true sight, alli hero, true, sight
# Topic 34:
# tree, path, unit tree, trap, place, trap place, enemi unit tree, hits, tree path, enemi path
# Topic 35:
# rang, attack rang, use, vision, power, form, transform, attacked, end, vision rang
# Topic 36:
# path, spike, burst, straight path, straight, stun damag, hurl, hurl air, air stun, air stun damag
# Topic 37:
# control, lifesteal, unit control, host, bodi, host bodi, unit, insid, alli hero, damag unit
# Topic 38:
# stun, damag stun, deal damag stun, damag, throw, deal, deal damag, stun deal, stun enemi, damag stun enemi
# Topic 39:
# slow, damag slow, slow movement, damag slow movement, slow movement speed, slow enemi, damag, movement, slow enemi unit, deal damag slow

# %%
# find the ability with `index` in descriptions DataFrame
# and define categories of this ability
index = 19
test = tfidf_vectorizer.transform([descriptions['description'][index]])
weights = nmf.transform(test)
topics = weights.argsort()[0][-3:]

print(descriptions['name'][index])
print(descriptions['description'][index])
print('-' * len(descriptions['name'][index]))

for topic in topics:
    for i in nmf.components_[topic].argsort()[-3:]:
        print(tf_features_names[i], end=', ')
        
    print()
# Out:
# fissure
# Slams the ground with a mighty totem, creating an impassable ridge of stone while stunning and damaging enemy units along its line.
# -------
# morphl, ani enemi, ani,
# deal damag, time, damag time,
# slam, stun, ground,

# %%
# distribution of categories
# %matplotlib inline
categories_dist = dict()
skills_by_category = dict()

for index, text in enumerate(descriptions['description']):
    vect = tfidf_vectorizer.transform([text])
    weights = nmf.transform(vect)
    topics = weights.argsort()[0][-2:]
    
    for topic in topics:
        # find words describing topic
        for i in nmf.components_[topic].argsort()[-1:]:
            skills_by_category.setdefault(tf_features_names[i], [])
            skills_by_category[tf_features_names[i]].append(descriptions['name'][index])
            
# categories_dist = categories_dist.dropna()
categories_dist = pd.Series({k: len(skills_by_category[k]) for k in skills_by_category})
# categories_dist.plot()

# %%
print('NOTE: the name of category can be misleading, check the above example with fissure')
print('#categories', categories_dist.shape[0])
print(categories_dist)
# Out:
# NOTE: the name of category can be misleading, check the above example with fissure
# #categories 39
# allow              11
# ani                12
# area               47
# armor              21
# attack             58
# attack speed       19
# bonus              11
# caus               24
# control            25
# creat               5
# critic              5
# damag enemi         3
# damag time         17
# damage            170
# dispel             25
# enemies            61
# friend              5
# ground             12
# heal                9
# health             40
# hero               40
# invis              10
# level              24
# mana               15
# movement speed     64
# nearbi enemi        1
# path               16
# percentag           4
# rang               24
# second             22
# seconds            43
# silenc             17
# slow               18
# stun               13
# teleport           18
# tree               19
# uniqu attack       16
# unit               20
# ward               12
# dtype: int64

# %%
# print abilities by category
print(skills_by_category['rang'])
# Out:
# ['morph_agi', 'morph_str', 'ether_shock', 'reincarnation', 'voodoo_restoration', 'sadist', 'lunar_blessing', 'dragon_tail', 'shadow_wave', 'battery_assault', 'darkness', 'flaming_lasso', 'invoke', 'drunken_brawler', 'primal_split', 'spirit_bear', 'true_form', 'spell_steal', 'thunder_strike', 'song_of_the_siren', 'stone_caller', 'reflection', 'tempest_double', 'untransform']

# %%
# print categories which were separated good enough from others
sorted_abilities = dict()
for category in skills_by_category:
    if len(skills_by_category[category]) <= 30:
        sorted_abilities[category] = skills_by_category[category]
        
pprint(sorted_abilities)
# Out:
# {'allow': ['reincarnation',
#            'guardian_angel',
#            'quas',
#            'wex',
#            'exort',
#            'invoke',
#            'deafening_blast',
#            'primal_split',
#            'conjure_image',
#            'splinter_blast',
#            'tempest_double'],
#  'ani': ['voodoo',
#          'morph_replicate',
#          'phase_shift',
#          'teleportation',
#          'wall_of_replica',
#          'devour',
#          'enrage',
#          'divided_we_stand',
#          'relocate',
#          'launch_snowball',
#          'mischief',
#          'untransform'],
#  'armor': ['berserkers_call',
#            'dark_lord',
#            'eye_of_the_storm',
#            'carrion_swarm',
#            'warcry',
#            'amplify_damage',
#            'gush',
#            'wave_of_terror',
#            'frost_armor',
#            'meld',
#            'dragon_blood',
#            'weave',
#            'the_swarm',
#            'acid_spray',
#            'forge_spirit',
#            'reality_rift',
#            'rip_tide',
#            'berserkers_rage',
#            'reactive_armor',
#            'viscous_nasal_goo',
#            'natural_order'],
#  'attack speed': ['blink',
#                   'grow',
#                   'inner_beast',
#                   'blink',
#                   'phantom_strike',
#                   'rage',
#                   'strafe',
#                   'chilling_touch',
#                   'overpower',
#                   'alacrity',
#                   'bloodlust',
#                   'null_field',
#                   'grave_chill',
#                   'stone_gaze',
#                   'fervor',
#                   'battle_trance',
#                   'press_the_attack',
#                   'fire_spirits',
#                   'winters_curse'],
#  'bonus': ['marksmanship',
#            'morph_agi',
#            'morph_str',
#            'brilliance_aura',
#            'blink_strike',
#            'refraction',
#            'psi_blades',
#            'goblins_greed',
#            'earth_pulverize',
#            'essence_shift',
#            'moment_of_courage'],
#  'caus': ['light_strike_array',
#           'voodoo',
#           'smoke_screen',
#           'permanent_invisibility',
#           'laser',
#           'blur',
#           'moon_glaive',
#           'lunar_blessing',
#           'shallow_grave',
#           'wind_walk',
#           'untouchable',
#           'crippling_fear',
#           'incapacitating_bite',
#           'geminate_attack',
#           'penitence',
#           'desolate',
#           'flak_cannon',
#           'drunken_haze',
#           'mana_leak',
#           'blinding_light',
#           'essence_shift',
#           'whirling_axes_melee',
#           'magnetic_field',
#           'jingu_mastery'],
#  'control': ['battle_hunger',
#              'finger_of_death',
#              'demonic_conversion',
#              'heat_seeking_missile',
#              'chronosphere',
#              'lightning_storm',
#              'teleportation',
#              'infest',
#              'consume',
#              'enchant',
#              'hand_of_god',
#              'global_silence',
#              'howl',
#              'feral_impulse',
#              'shapeshift',
#              'storm_cyclone',
#              'disruption',
#              'chaos_strike',
#              'mirror_image',
#              'skewer',
#              'moment_of_courage',
#              'magnetize',
#              'reflection',
#              'control',
#              'cloud'],
#  'creat': ['ether_shock',
#            'reality',
#            'whirling_axes_ranged',
#            'ice_shards',
#            'frozen_sigil'],
#  'critic': ['coup_de_grace',
#             'jinada',
#             'thunder_strike',
#             'spirit_form',
#             'walrus_punch'],
#  'damag enemi': ['sonic_wave', 'shadow_wave', 'shockwave'],
#  'damag time': ['fissure',
#                 'dismember',
#                 'hellfire_blast',
#                 'chain_frost',
#                 'paralyzing_cask',
#                 'shadow_word',
#                 'hawk_invisibility',
#                 'venomous_gale',
#                 'poison_nova',
#                 'viper_strike',
#                 'lucent_beam',
#                 'homing_missile',
#                 'shadow_poison',
#                 'gravekeepers_cloak',
#                 'stone_caller',
#                 'icarus_dive',
#                 'flux'],
#  'dispel': ['blade_fury',
#             'doppelwalk',
#             'unstable_current',
#             'kraken_shell',
#             'rearm',
#             'corrosive_skin',
#             'rage',
#             'infest',
#             'repel',
#             'time_lapse',
#             'doom',
#             'tornado',
#             'storm_dispel_magic',
#             'demonic_purge',
#             'phantasm',
#             'divided_we_stand',
#             'mirror_image',
#             'dark_pact',
#             'aphotic_shield',
#             'borrowed_time',
#             'press_the_attack',
#             'supernova',
#             'false_promise',
#             'assimilate',
#             'spark_wraith'],
#  'friend': ['morph_replicate',
#             'nether_swap',
#             'shadow_word',
#             'ion_shell',
#             'charge_of_darkness'],
#  'ground': ['fissure',
#             'echo_slam',
#             'avalanche',
#             'slithereen_crush',
#             'ravage',
#             'thunder_clap',
#             'telekinesis',
#             'hoof_stomp',
#             'shockwave',
#             'echo_stomp',
#             'boulder_smash',
#             'boundless_strike'],
#  'heal': ['bloodrage',
#           'voodoo_restoration',
#           'life_drain',
#           'inner_vitality',
#           'scorched_earth',
#           'fire_permanent_immolation',
#           'soul_rip',
#           'null_field',
#           'death_coil'],
#  'invis': ['invis',
#            'sprint',
#            'call_of_the_wild',
#            'hawk_invisibility',
#            'chronosphere',
#            'wind_walk',
#            'earthbind',
#            'overgrowth',
#            'stasis_trap',
#            'remote_mines'],
#  'level': ['toss',
#            'frostbite',
#            'call_of_the_wild',
#            'plague_ward',
#            'hunter_in_the_night',
#            'holy_persuasion',
#            'nether_strike',
#            'exort',
#            'cold_snap',
#            'ghost_walk',
#            'tornado',
#            'emp',
#            'alacrity',
#            'chaos_meteor',
#            'sun_strike',
#            'forge_spirit',
#            'ice_wall',
#            'deafening_blast',
#            'essence_aura',
#            'summon_wolves',
#            'decay',
#            'soul_assumption',
#            'bristleback',
#            'atrophy_aura'],
#  'mana': ['mana_void',
#           'mana_drain',
#           'ball_lightning',
#           'brilliance_aura',
#           'dark_ritual',
#           'time_lapse',
#           'emp',
#           'essence_aura',
#           'sanity_eclipse',
#           'mana_burn',
#           'unrefined_fireblast',
#           'mana_leak',
#           'chakra_magic',
#           'mystic_snake',
#           'mana_shield'],
#  'nearbi enemi': ['arc_lightning'],
#  'path': ['dragon_slave',
#           'impale',
#           'waveform',
#           'illusory_orb',
#           'waning_rift',
#           'wild_axes',
#           'primal_roar',
#           'surge',
#           'the_swarm',
#           'dual_breath',
#           'ice_path',
#           'firefly',
#           'ignite',
#           'impale',
#           'walrus_punch',
#           'launch_snowball'],
#  'percentag': ['rupture', 'fatal_bonds', 'lucent_beam', 'sun_ray'],
#  'rang': ['morph_agi',
#           'morph_str',
#           'ether_shock',
#           'reincarnation',
#           'voodoo_restoration',
#           'sadist',
#           'lunar_blessing',
#           'dragon_tail',
#           'shadow_wave',
#           'battery_assault',
#           'darkness',
#           'flaming_lasso',
#           'invoke',
#           'drunken_brawler',
#           'primal_split',
#           'spirit_bear',
#           'true_form',
#           'spell_steal',
#           'thunder_strike',
#           'song_of_the_siren',
#           'stone_caller',
#           'reflection',
#           'tempest_double',
#           'untransform'],
#  'second': ['nightmare',
#             'mana_drain',
#             'starfall',
#             'frostbite',
#             'maledict',
#             'tricks_of_the_trade',
#             'midnight_pulse',
#             'rain_of_chaos',
#             'golem_permanent_immolation',
#             'psionic_trap',
#             'corrosive_skin',
#             'pulse_nova',
#             'macropyre',
#             'infernal_blade',
#             'acid_spray',
#             'ice_wall',
#             'overcharge',
#             'searing_chains',
#             'flame_guard',
#             'launch_fire_spirit',
#             'cold_embrace',
#             'spirit_siphon'],
#  'silenc': ['silence',
#             'aftershock',
#             'silence',
#             'great_cleave',
#             'arc_lightning',
#             'ravage',
#             'command_aura',
#             'scream_of_pain',
#             'purification',
#             'rocket_barrage',
#             'glaives_of_wisdom',
#             'last_word',
#             'global_silence',
#             'earth_spell_immunity',
#             'fire_permanent_immolation',
#             'hoof_stomp',
#             'ancient_seal'],
#  'slow': ['phase_shift',
#           'storm_bolt',
#           'magic_missile',
#           'crystal_nova',
#           'psionic_trap',
#           'incapacitating_bite',
#           'earthshock',
#           'call_down',
#           'geostrike',
#           'flesh_golem',
#           'whirling_axes_ranged',
#           'frozen_sigil',
#           'arcane_bolt',
#           'activate_fire_remnant',
#           'focused_detonate',
#           'arctic_burn',
#           'time_dilation',
#           'primal_spring'],
#  'stun': ['arrow',
#           'adaptive_strike',
#           'lightning_bolt',
#           'slithereen_crush',
#           'bash',
#           'shackleshot',
#           'eclipse',
#           'greater_bash',
#           'unstable_concoction',
#           'earth_hurl_boulder',
#           'chaos_bolt',
#           'fireblast',
#           'activate_fire_remnant'],
#  'teleport': ['blink',
#               'spell_shield',
#               'marksmanship',
#               'torrent',
#               'illusory_orb',
#               'ethereal_jaunt',
#               'blink',
#               'coup_de_grace',
#               'split_earth',
#               'strafe',
#               'overpower',
#               'disruption',
#               'earthbind',
#               'poof',
#               'kinetic_field',
#               'recall',
#               'relocate',
#               'dark_rift'],
#  'tree': ['dragon_slave',
#           'waveform',
#           'plasma_field',
#           'shackleshot',
#           'powershot',
#           'paralyzing_cask',
#           'march_of_the_machines',
#           'wild_axes',
#           'trap',
#           'sprout',
#           'spectral_dagger',
#           'natures_guise',
#           'illuminate',
#           'whirling_death',
#           'timber_chain',
#           'chakram',
#           'stasis_trap',
#           'tree_dance',
#           'primal_spring'],
#  'uniqu attack': ['mana_break',
#                   'frost_arrows',
#                   'juxtapose',
#                   'phantom_edge',
#                   'ethereal_jaunt',
#                   'voodoo',
#                   'chain_frost',
#                   'golem_flaming_fists',
#                   'blur',
#                   'searing_arrows',
#                   'geminate_attack',
#                   'hand_of_god',
#                   'arcane_orb',
#                   'split_shot',
#                   'metamorphosis',
#                   'magnetic_field'],
#  'unit': ['brain_sap',
#           'laguna_blade',
#           'voodoo',
#           'spirit_lance',
#           'meat_hook',
#           'carrion_swarm',
#           'electric_vortex',
#           'purification',
#           'void',
#           'spawn_spiderlings',
#           'spawn_spiderite',
#           'shuriken_toss',
#           'test_of_faith',
#           'charge_of_darkness',
#           'storm_cyclone',
#           'leech_seed',
#           'chakra_magic',
#           'pit_of_malice',
#           'dark_rift',
#           'walrus_kick'],
#  'ward': ['healing_ward',
#           'mass_serpent_ward',
#           'death_ward',
#           'plague_ward',
#           'nether_ward',
#           'sprout',
#           'darkness',
#           'reality',
#           'cold_feet',
#           'summon_wolves',
#           'earth_spell_immunity',
#           'ensnare']}
