# %%
import numpy as np
import pandas as pd

from atod import Hero, Heroes, Ability, Abilities

# %%
# just random heroes ids
pick = Heroes.from_ids([1, 5, 28, 65, 12])
print(pick.get_names())
print(pick.get_summary())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-da09afb6ea1f> in <module>()
#       1 # just random heroes ids
#       2 pick = Heroes([1, 5, 28, 65, 12])
# ----> 3 print(pick.get_names())
#       4 print(pick.get_summary())
#
# /Users/gasabr/AtoD/atod/heroes.py in get_names(self)
#     238
#     239     def get_names(self):
# --> 240         return [m.name for m in self.members]
#     241
#     242     @classmethod
#
# /Users/gasabr/AtoD/atod/heroes.py in <listcomp>(.0)
#     238
#     239     def get_names(self):
# --> 240         return [m.name for m in self.members]
#     241
#     242     @classmethod
#
# AttributeError: 'int' object has no attribute 'name'

# %%
a = Heroes.all().get_list()
# Out:
# {'ArmorPhysical': -1.0,
#  'AttackAcquisitionRange': 600,
#  'AttackAnimationPoint': 0.3,
#  'AttackCapabilities': 'DOTA_UNIT_CAP_MELEE_ATTACK',
#  'AttackDamageMax': 31,
#  'AttackDamageMin': 27,
#  'AttackRange': 150,
#  'AttackRate': 1.45,
#  'AttributeAgilityGain': 2.8,
#  'AttributeBaseAgility': 22,
#  'AttributeBaseIntelligence': 15,
#  'AttributeBaseStrength': 22,
#  'AttributeIntelligenceGain': 1.8,
#  'AttributePrimary': 'DOTA_ATTRIBUTE_AGILITY',
#  'AttributeStrengthGain': 1.2,
#  'HeroID': 1,
#  'HeroType': 'DOTA_BOT_HARD_CARRY',
#  'MovementSpeed': 315,
#  'MovementTurnRate': 0.5,
#  'ProvidesBabysit': 0,
#  'ProvidesSetup': 0,
#  'RequiresBabysit': 2,
#  'RequiresFarm': 2,
#  'RequiresSetup': 1,
#  'Role': 'Carry,Escape,Nuker',
#  'Rolelevels': '3,3,1',
#  'SoloDesire': 1,
#  'SurvivalRating': 2,
#  'Team': 'Good',
#  '_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x108c41978>,
#  'aliases': 'am',
#  'in_game_name': 'antimage',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-c53f4e423b6d> in <module>()
# ----> 1 a.shape()
#
# TypeError: 'tuple' object is not callable
